# %%
import os
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

from tqdm import tqdm

from scipy.stats import norm, multivariate_normal
from scipy.interpolate import griddata

from torch.distributions.multivariate_normal import MultivariateNormal

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
d = 2
m = 1
N = 100
xbounds = np.array([[-25, 25],
                    [-25, 25]])
ϕ = lambda x, μ, Σ, H: (Σ @ H.T).T @ (x - μ)

# %%
# def sample_random_gaussian(N, d):
#     μ = torch.rand(d)
#     keep_sampling = True
#     while keep_sampling:
#         Σ = torch.rand(d, d)**2
#         Σ = torch.tril(Σ)
#         Σ = Σ + Σ.T
#         if torch.linalg.det(Σ) > 0:
#             keep_sampling=False
#     dist = MultivariateNormal(loc=μ, covariance_matrix=Σ)
#     X = dist.rsample((N,)).T
#     return X, dist

# %%
def random_dist(d, loc, scale):
    μ = torch.rand(d)*loc
    keep_sampling = True
    while keep_sampling:
        Σ = torch.abs(torch.rand(d, d)) * scale
        Σ = torch.tril(Σ)
        Σ = Σ + Σ.T - Σ*torch.eye(d)
        if torch.linalg.det(Σ) > 0:
            keep_sampling=False
    dist = MultivariateNormal(loc=μ, covariance_matrix=Σ)
    return dist

# %%
x_1 = torch.linspace(xbounds[0, 0], xbounds[0, 1], N)
x_2 = torch.linspace(xbounds[1, 0], xbounds[1, 1], N)
x1_mat, x2_mat = torch.meshgrid(x_1, x_2, indexing='xy')

# %%
X = torch.stack([x1_mat, x2_mat], dim=0)

# %%
def plot_functions(X, px, hx, ϕx):
    
    x1_mat = X[0]
    x2_mat = X[1]
    
    fig, axes = plt.subplots(1, 3, figsize=(14, 3))
    
    im = axes[0].scatter(x1_mat, x2_mat, c=px[0])
    axes[0].set_xlim(xbounds[0, 0], xbounds[0, 1])
    axes[0].set_ylim(xbounds[1, 0], xbounds[1, 1])
    axes[0].set_title('$p(x)$')
    plt.colorbar(im)
    
    
    im = axes[1].scatter(x1_mat, x2_mat, c=hx[0])
    axes[1].set_xlim(xbounds[0, 0], xbounds[0, 1])
    axes[1].set_ylim(xbounds[1, 0], xbounds[1, 1])
    axes[1].set_title('$h(x)$')
    plt.colorbar(im)
    
    im = axes[2].scatter(x1_mat, x2_mat, c=ϕx[0])
    axes[2].set_xlim(xbounds[0, 0], xbounds[0, 1])
    axes[2].set_ylim(xbounds[1, 0], xbounds[1, 1])
    axes[2].set_title('$\phi(x)$')
    plt.colorbar(im)

    return fig

# %%
ax = []
ux = []
for i in range(1000):
    dist = random_dist(d, loc=10, scale=36)
    H = torch.randn(m, d) * 1e-2
    px = torch.exp(dist.log_prob(X.T))[None, ...]
    hx = (H @ X.flatten(1)).reshape((m, N, N))
    ϕx = ϕ(X.flatten(1), dist.loc[:, None], dist.covariance_matrix, H).reshape((m, N, N))

    if i < 5:
        _ = plot_functions(X, px, hx, ϕx)
        _ = plt.show()
        _ = plt.clf()

    ax.append(torch.concat([px, hx], dim=0))
    ux.append(ϕx)

ax = torch.stack(ax)
ux = torch.stack(ux)
# Out:
# /tmp/ipykernel_31072/4190411745.py:6: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1708025845868/work/aten/src/ATen/native/TensorShape.cpp:3637.)
#   px = torch.exp(dist.log_prob(X.T))[None, ...]

# %%
from sklearn.model_selection import train_test_split

# Split ax and ux into train and test sets
ax_train, ax_test, ux_train, ux_test = train_test_split(ax, ux, test_size=0.2, 
                                                        random_state=42)

# %%
data_dir = f'data/{str(dt.date.today())}'
os.makedirs(data_dir, exist_ok=True)

# %%
torch.save(ax_train, os.path.join(data_dir, 'ax_train.pt'))
torch.save(ax_test, os.path.join(data_dir, 'ax_test.pt'))
torch.save(ux_train, os.path.join(data_dir, 'ux_train.pt'))
torch.save(ux_test, os.path.join(data_dir, 'ux_test.pt'))
