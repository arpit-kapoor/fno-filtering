# %%
import pandas as pd

# %%
results_df = pd.read_csv('../results.csv')
results_df
# Out:
#     $\mu$  $\sigma$    h1_error    r2_int  r2_noint   rmse_int  rmse_noint
# 0  -15.97      3.30   28.793371  0.959318  0.957727   8.291862    8.452432
# 1   17.62      4.03   48.641189 -0.075626 -0.083233  39.212338   39.350756
# 2    0.13      2.14  113.210657 -0.490160 -0.495669  13.553716   13.578748
# 3    7.41      2.62   28.893239  0.969143  0.964738   4.173926    4.461892
# 4   -7.62      2.88  133.864435 -2.126456 -2.123619  35.290417   35.274402
# 5   -6.03      4.22   26.832771  0.759817  0.759799  47.260404   47.262224
# 6   -5.48      3.54   27.166958  0.913536  0.912360  18.798578   18.925991
# 7   -1.41      5.00   20.515008  0.988675  0.988236  21.791328   22.210379
# 8  -16.58      4.83   60.128616  0.589595  0.588744  70.995731   71.069292
# 9   -2.08      3.11   31.905486  0.544749  0.541098   9.408045    9.445701
# 10  -3.52      4.72   13.704624  0.990340  0.989899  18.407703   18.823312

# %%
print(results_df.sort_values(by='r2_int', ascending=False).to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrrr}
# \toprule
# $\mu$ & $\sigma$ & h1_error & r2_int & r2_noint & rmse_int & rmse_noint \\
# \midrule
# -3.520000 & 4.720000 & 13.704624 & 0.990340 & 0.989899 & 18.407703 & 18.823312 \\
# -1.410000 & 5.000000 & 20.515008 & 0.988675 & 0.988236 & 21.791328 & 22.210379 \\
# 7.410000 & 2.620000 & 28.893239 & 0.969143 & 0.964738 & 4.173926 & 4.461892 \\
# -15.970000 & 3.300000 & 28.793371 & 0.959318 & 0.957727 & 8.291862 & 8.452432 \\
# -5.480000 & 3.540000 & 27.166958 & 0.913536 & 0.912360 & 18.798578 & 18.925991 \\
# -6.030000 & 4.220000 & 26.832771 & 0.759817 & 0.759799 & 47.260404 & 47.262224 \\
# -16.580000 & 4.830000 & 60.128616 & 0.589595 & 0.588744 & 70.995731 & 71.069292 \\
# -2.080000 & 3.110000 & 31.905486 & 0.544749 & 0.541098 & 9.408045 & 9.445701 \\
# 17.620000 & 4.030000 & 48.641189 & -0.075626 & -0.083233 & 39.212338 & 39.350756 \\
# 0.130000 & 2.140000 & 113.210657 & -0.490160 & -0.495669 & 13.553716 & 13.578748 \\
# -7.620000 & 2.880000 & 133.864435 & -2.126456 & -2.123619 & 35.290417 & 35.274402 \\
# \bottomrule
# \end{tabular}
